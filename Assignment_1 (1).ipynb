# %%
import pandas as pd
file=pd.read_excel("/content/work aiml.xlsx")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organisation  Unnamed: 6  \
# 0    1     tej   male       india         NaN       google         NaN
# 1    2    yogi   male       china         NaN       amazon         NaN
# 2    3     ram   male       nepal         NaN    microsoft         NaN
# 3    4  charan   male         usa         NaN        wipro         NaN
#
#    workexperience(in years)
# 0                        20
# 1                         8
# 2                        12
# 3                        17

# %%
import pandas as pd
file=pd.read_table("/content/work aiml.txt")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organisation  Unnamed: 6  \
# 0    1     tej   male       india         NaN       google         NaN
# 1    2    yogi   male       china         NaN       amazon         NaN
# 2    3     ram   male       nepal         NaN    microsoft         NaN
# 3    4  charan   male         usa         NaN        wipro         NaN
#
#    workexperience(in years)
# 0                        20
# 1                         8
# 2                        12
# 3                        17

# %%
import pandas as pd
file=pd.read_csv("/content/work aiml.csv")
file
# Out:
#    sno    name gender nationality  Unnamed: 4 organisation  Unnamed: 6  \
# 0    1     tej   male       india         NaN       google         NaN
# 1    2    yogi   male       china         NaN       amazon         NaN
# 2    3     ram   male       nepal         NaN    microsoft         NaN
# 3    4  charan   male         usa         NaN        wipro         NaN
#
#    workexperience(in years)
# 0                        20
# 1                         8
# 2                        12
# 3                        17
